# %%
import numpy as np
import tensorflow.compat.v1 as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, Sequential, Input
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from generator import Generator

# %%
def plot():
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_loss(history):
    plt.plot(history.history['loss'], label='loss', marker=".")
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Error [MPG]')
    plot()
    
def pre_process_isotherm(isotherm):
    isotherm -= min(isotherm)
    isotherm /= max(isotherm)
    return isotherm
    
def load_dataset(path):
    min_exp_pressure_i = 40
    max_exp_pressure_i =  547 # silcia 458 # carbon 547
    with open(path, 'rb') as f:
            dataset = np.load(f)
            isotherm_data = dataset["isotherm_data"]
            pore_distribution_data = dataset["pore_distribution_data"]
    x = np.empty((isotherm_data.shape[0], (-min_exp_pressure_i + max_exp_pressure_i)))
    y = np.empty(pore_distribution_data.shape)
    for i in range(len(isotherm_data)):
        isotherm = pre_process_isotherm(isotherm_data[i][min_exp_pressure_i:max_exp_pressure_i])
        pore_distribution = pre_process_isotherm(pore_distribution_data[i])
        x[i] = isotherm
        y[i] = pore_distribution
    x, y = shuffle(x, y)
    return x, y

def create_model():
    ## DENSE NET
    model = Sequential(
        [
            Input(shape=len(x_train[0],)),
            layers.Dense(400, activation='relu'),
            layers.Dense(400, activation='relu'),
            layers.Dense(400, activation='relu'),
            layers.Dense(400, activation='relu'),
            layers.Dense(400, activation='relu'),
            layers.Dense(400, activation='relu'),
            layers.Dense(400, activation='relu'),
            layers.Dense(len(y_train[0]), activation='relu')
        ]
    )
    model.compile(loss='mean_squared_error', optimizer='Adam')
    return model

# %%
x, y = load_dataset('data/datasets/Silica_medium.npz')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 x, y = load_dataset('data/datasets/Silica_medium.npz')
#
# Cell In[64], line 30, in load_dataset(path)
#      28     isotherm = pre_process_isotherm(isotherm_data[i][min_exp_pressure_i:max_exp_pressure_i])
#      29     pore_distribution = pre_process_isotherm(pore_distribution_data[i])
# ---> 30     x[i] = isotherm
#      31     y[i] = pore_distribution
#      32 x, y = shuffle(x, y)
#
# ValueError: could not broadcast input array from shape (418,) into shape (507,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
model = create_model()

# %%
# from keras import backend as K
# K.set_value(model.optimizer.learning_rate, 0.0001)
mcp_save = tf.keras.callbacks.ModelCheckpoint(filepath='data/models/silica_medium_relu.keras', save_best_only=True,
                                           monitor='val_loss', mode='min', verbose=1, save_weights_only=False,
                                           save_freq='epoch')

reduce_lr_loss = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                                   patience=100, verbose=1, mode='auto')
history = model.fit(np.array(x_train), np.array(y_train),
                    epochs=1000, batch_size=1000, shuffle=True,
                    validation_data=(np.array(x_test), np.array(y_test)), callbacks=[mcp_save, reduce_lr_loss])
plot_loss(history)
# Out:
# Epoch 1/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0654
# Epoch 1: val_loss improved from inf to 0.04182, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 15s 49ms/step - loss: 0.0653 - val_loss: 0.0418 - lr: 0.0010
# Epoch 2/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0371
# Epoch 2: val_loss improved from 0.04182 to 0.04081, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0371 - val_loss: 0.0408 - lr: 0.0010
# Epoch 3/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0326
# Epoch 3: val_loss improved from 0.04081 to 0.03348, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0326 - val_loss: 0.0335 - lr: 0.0010
# Epoch 4/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0308
# Epoch 4: val_loss did not improve from 0.03348
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0308 - val_loss: 0.0390 - lr: 0.0010
# Epoch 5/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0286
# Epoch 5: val_loss improved from 0.03348 to 0.02158, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 42ms/step - loss: 0.0286 - val_loss: 0.0216 - lr: 0.0010
# Epoch 6/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0243
# Epoch 6: val_loss did not improve from 0.02158
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0244 - val_loss: 0.0298 - lr: 0.0010
# Epoch 7/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0230
# Epoch 7: val_loss did not improve from 0.02158
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0231 - val_loss: 0.0289 - lr: 0.0010
# Epoch 8/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0234
# Epoch 8: val_loss did not improve from 0.02158
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0234 - val_loss: 0.0227 - lr: 0.0010
# Epoch 9/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0221
# Epoch 9: val_loss did not improve from 0.02158
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0222 - val_loss: 0.0545 - lr: 0.0010
# Epoch 10/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0222
# Epoch 10: val_loss improved from 0.02158 to 0.01924, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0222 - val_loss: 0.0192 - lr: 0.0010
# Epoch 11/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0203
# Epoch 11: val_loss did not improve from 0.01924
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0204 - val_loss: 0.0414 - lr: 0.0010
# Epoch 12/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 12: val_loss improved from 0.01924 to 0.01692, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 12s 42ms/step - loss: 0.0204 - val_loss: 0.0169 - lr: 0.0010
# Epoch 13/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0187
# Epoch 13: val_loss did not improve from 0.01692
# 300/300 [==============================] - 12s 42ms/step - loss: 0.0187 - val_loss: 0.0191 - lr: 0.0010
# Epoch 14/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0185
# Epoch 14: val_loss improved from 0.01692 to 0.01576, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0185 - val_loss: 0.0158 - lr: 0.0010
# Epoch 15/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0203
# Epoch 15: val_loss improved from 0.01576 to 0.01391, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 12s 42ms/step - loss: 0.0202 - val_loss: 0.0139 - lr: 0.0010
# Epoch 16/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0176
# Epoch 16: val_loss did not improve from 0.01391
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0176 - val_loss: 0.0158 - lr: 0.0010
# Epoch 17/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0177
# Epoch 17: val_loss did not improve from 0.01391
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0177 - val_loss: 0.0166 - lr: 0.0010
# Epoch 18/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0169
# Epoch 18: val_loss did not improve from 0.01391
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0169 - val_loss: 0.0159 - lr: 0.0010
# Epoch 19/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 19: val_loss did not improve from 0.01391
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0160 - val_loss: 0.0139 - lr: 0.0010
# Epoch 20/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0169
# Epoch 20: val_loss improved from 0.01391 to 0.01191, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0169 - val_loss: 0.0119 - lr: 0.0010
# Epoch 21/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0158
# Epoch 21: val_loss did not improve from 0.01191
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0158 - val_loss: 0.0201 - lr: 0.0010
# Epoch 22/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0170
# Epoch 22: val_loss did not improve from 0.01191
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0170 - val_loss: 0.0137 - lr: 0.0010
# Epoch 23/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0148
# Epoch 23: val_loss did not improve from 0.01191
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0148 - val_loss: 0.0164 - lr: 0.0010
# Epoch 24/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0190
# Epoch 24: val_loss did not improve from 0.01191
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0190 - val_loss: 0.0166 - lr: 0.0010
# Epoch 25/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 25: val_loss improved from 0.01191 to 0.01091, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0166 - val_loss: 0.0109 - lr: 0.0010
# Epoch 26/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0154
# Epoch 26: val_loss improved from 0.01091 to 0.00983, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0153 - val_loss: 0.0098 - lr: 0.0010
# Epoch 27/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0150
# Epoch 27: val_loss did not improve from 0.00983
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0150 - val_loss: 0.0152 - lr: 0.0010
# Epoch 28/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0151
# Epoch 28: val_loss did not improve from 0.00983
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0151 - val_loss: 0.0112 - lr: 0.0010
# Epoch 29/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0153
# Epoch 29: val_loss did not improve from 0.00983
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0153 - val_loss: 0.0164 - lr: 0.0010
# Epoch 30/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0152
# Epoch 30: val_loss did not improve from 0.00983
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0152 - val_loss: 0.0365 - lr: 0.0010
# Epoch 31/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0154
# Epoch 31: val_loss did not improve from 0.00983
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0154 - val_loss: 0.0165 - lr: 0.0010
# Epoch 32/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0148
# Epoch 32: val_loss did not improve from 0.00983
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0148 - val_loss: 0.0160 - lr: 0.0010
# Epoch 33/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0134
# Epoch 33: val_loss improved from 0.00983 to 0.00974, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0134 - val_loss: 0.0097 - lr: 0.0010
# Epoch 34/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0137
# Epoch 34: val_loss improved from 0.00974 to 0.00941, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0137 - val_loss: 0.0094 - lr: 0.0010
# Epoch 35/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0130
# Epoch 35: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0130 - val_loss: 0.0114 - lr: 0.0010
# Epoch 36/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0129
# Epoch 36: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0129 - val_loss: 0.0147 - lr: 0.0010
# Epoch 37/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0133
# Epoch 37: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0133 - val_loss: 0.0117 - lr: 0.0010
# Epoch 38/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0152
# Epoch 38: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0152 - val_loss: 0.0134 - lr: 0.0010
# Epoch 39/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0136
# Epoch 39: val_loss did not improve from 0.00941
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0136 - val_loss: 0.0133 - lr: 0.0010
# Epoch 40/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0125
# Epoch 40: val_loss did not improve from 0.00941
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0125 - val_loss: 0.0124 - lr: 0.0010
# Epoch 41/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0127
# Epoch 41: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0127 - val_loss: 0.0118 - lr: 0.0010
# Epoch 42/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0118
# Epoch 42: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0118 - val_loss: 0.0128 - lr: 0.0010
# Epoch 43/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0123
# Epoch 43: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0123 - val_loss: 0.0277 - lr: 0.0010
# Epoch 44/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0128
# Epoch 44: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0128 - val_loss: 0.0105 - lr: 0.0010
# Epoch 45/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0132
# Epoch 45: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0132 - val_loss: 0.0120 - lr: 0.0010
# Epoch 46/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0124
# Epoch 46: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0124 - val_loss: 0.0112 - lr: 0.0010
# Epoch 47/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0129
# Epoch 47: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0129 - val_loss: 0.0122 - lr: 0.0010
# Epoch 48/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0124
# Epoch 48: val_loss did not improve from 0.00941
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0124 - val_loss: 0.0180 - lr: 0.0010
# Epoch 49/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 49: val_loss improved from 0.00941 to 0.00875, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0138 - val_loss: 0.0087 - lr: 0.0010
# Epoch 50/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0125
# Epoch 50: val_loss did not improve from 0.00875
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0125 - val_loss: 0.0095 - lr: 0.0010
# Epoch 51/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0105
# Epoch 51: val_loss did not improve from 0.00875
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0105 - val_loss: 0.0160 - lr: 0.0010
# Epoch 52/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0126
# Epoch 52: val_loss did not improve from 0.00875
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0126 - val_loss: 0.0088 - lr: 0.0010
# Epoch 53/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0125
# Epoch 53: val_loss did not improve from 0.00875
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0125 - val_loss: 0.0117 - lr: 0.0010
# Epoch 54/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0118
# Epoch 54: val_loss did not improve from 0.00875
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0118 - val_loss: 0.0159 - lr: 0.0010
# Epoch 55/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 55: val_loss did not improve from 0.00875
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0131 - val_loss: 0.0106 - lr: 0.0010
# Epoch 56/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0109
# Epoch 56: val_loss did not improve from 0.00875
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0109 - val_loss: 0.0116 - lr: 0.0010
# Epoch 57/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0115
# Epoch 57: val_loss improved from 0.00875 to 0.00798, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0115 - val_loss: 0.0080 - lr: 0.0010
# Epoch 58/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0146
# Epoch 58: val_loss did not improve from 0.00798
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0146 - val_loss: 0.0087 - lr: 0.0010
# Epoch 59/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 59: val_loss did not improve from 0.00798
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0112 - val_loss: 0.0090 - lr: 0.0010
# Epoch 60/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0118
# Epoch 60: val_loss did not improve from 0.00798
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0118 - val_loss: 0.0114 - lr: 0.0010
# Epoch 61/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 61: val_loss did not improve from 0.00798
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0110 - val_loss: 0.0098 - lr: 0.0010
# Epoch 62/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 62: val_loss did not improve from 0.00798
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0110 - val_loss: 0.0137 - lr: 0.0010
# Epoch 63/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 63: val_loss did not improve from 0.00798
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0112 - val_loss: 0.0080 - lr: 0.0010
# Epoch 64/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 64: val_loss did not improve from 0.00798
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0114 - val_loss: 0.0170 - lr: 0.0010
# Epoch 65/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0105
# Epoch 65: val_loss did not improve from 0.00798
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0105 - val_loss: 0.0096 - lr: 0.0010
# Epoch 66/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0104
# Epoch 66: val_loss improved from 0.00798 to 0.00777, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0103 - val_loss: 0.0078 - lr: 0.0010
# Epoch 67/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 67: val_loss did not improve from 0.00777
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0114 - val_loss: 0.0107 - lr: 0.0010
# Epoch 68/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0109
# Epoch 68: val_loss did not improve from 0.00777
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0109 - val_loss: 0.0087 - lr: 0.0010
# Epoch 69/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 69: val_loss did not improve from 0.00777
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0100 - val_loss: 0.0080 - lr: 0.0010
# Epoch 70/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0125
# Epoch 70: val_loss did not improve from 0.00777
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0125 - val_loss: 0.0183 - lr: 0.0010
# Epoch 71/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0117
# Epoch 71: val_loss improved from 0.00777 to 0.00741, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0117 - val_loss: 0.0074 - lr: 0.0010
# Epoch 72/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 72: val_loss improved from 0.00741 to 0.00740, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0097 - val_loss: 0.0074 - lr: 0.0010
# Epoch 73/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 73: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0104 - val_loss: 0.0075 - lr: 0.0010
# Epoch 74/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0109
# Epoch 74: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0109 - val_loss: 0.0111 - lr: 0.0010
# Epoch 75/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 75: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0100 - val_loss: 0.0086 - lr: 0.0010
# Epoch 76/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 76: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0108 - val_loss: 0.0111 - lr: 0.0010
# Epoch 77/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0105
# Epoch 77: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0106 - val_loss: 0.0117 - lr: 0.0010
# Epoch 78/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 78: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0096 - val_loss: 0.0119 - lr: 0.0010
# Epoch 79/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 79: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0097 - val_loss: 0.0090 - lr: 0.0010
# Epoch 80/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0109
# Epoch 80: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0110 - val_loss: 0.0251 - lr: 0.0010
# Epoch 81/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0113
# Epoch 81: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0113 - val_loss: 0.0091 - lr: 0.0010
# Epoch 82/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0117
# Epoch 82: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0117 - val_loss: 0.0095 - lr: 0.0010
# Epoch 83/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 83: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0102 - val_loss: 0.0088 - lr: 0.0010
# Epoch 84/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 84: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0096 - val_loss: 0.0123 - lr: 0.0010
# Epoch 85/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0105
# Epoch 85: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0105 - val_loss: 0.0116 - lr: 0.0010
# Epoch 86/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 86: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0095 - val_loss: 0.0111 - lr: 0.0010
# Epoch 87/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 87: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0091 - val_loss: 0.0081 - lr: 0.0010
# Epoch 88/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 88: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0095 - val_loss: 0.0106 - lr: 0.0010
# Epoch 89/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 89: val_loss did not improve from 0.00740
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0092 - val_loss: 0.0135 - lr: 0.0010
# Epoch 90/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 90: val_loss improved from 0.00740 to 0.00614, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0108 - val_loss: 0.0061 - lr: 0.0010
# Epoch 91/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 91: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0097 - val_loss: 0.0067 - lr: 0.0010
# Epoch 92/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0103
# Epoch 92: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0103 - val_loss: 0.0111 - lr: 0.0010
# Epoch 93/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0104
# Epoch 93: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0104 - val_loss: 0.0157 - lr: 0.0010
# Epoch 94/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0121
# Epoch 94: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0121 - val_loss: 0.0088 - lr: 0.0010
# Epoch 95/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 95: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0088 - val_loss: 0.0097 - lr: 0.0010
# Epoch 96/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 96: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0097 - val_loss: 0.0094 - lr: 0.0010
# Epoch 97/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 97: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0099 - val_loss: 0.0086 - lr: 0.0010
# Epoch 98/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 98: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0097 - val_loss: 0.0099 - lr: 0.0010
# Epoch 99/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 99: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0096 - val_loss: 0.0074 - lr: 0.0010
# Epoch 100/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 100: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0093 - val_loss: 0.0089 - lr: 0.0010
# Epoch 101/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 101: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0097 - val_loss: 0.0065 - lr: 0.0010
# Epoch 102/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 102: val_loss did not improve from 0.00614
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0093 - val_loss: 0.0063 - lr: 0.0010
# Epoch 103/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 103: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0097 - val_loss: 0.0068 - lr: 0.0010
# Epoch 104/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 104: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0090 - val_loss: 0.0080 - lr: 0.0010
# Epoch 105/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 105: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 44ms/step - loss: 0.0102 - val_loss: 0.0092 - lr: 0.0010
# Epoch 106/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 106: val_loss did not improve from 0.00614
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0092 - val_loss: 0.0069 - lr: 0.0010
# Epoch 107/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 107: val_loss did not improve from 0.00614
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0090 - val_loss: 0.0093 - lr: 0.0010
# Epoch 108/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 108: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0091 - val_loss: 0.0075 - lr: 0.0010
# Epoch 109/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0094
# Epoch 109: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0094 - val_loss: 0.0115 - lr: 0.0010
# Epoch 110/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 110: val_loss did not improve from 0.00614
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0092 - val_loss: 0.0078 - lr: 0.0010
# Epoch 111/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 111: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0089 - val_loss: 0.0068 - lr: 0.0010
# Epoch 112/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 112: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0092 - val_loss: 0.0072 - lr: 0.0010
# Epoch 113/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 113: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0083 - val_loss: 0.0103 - lr: 0.0010
# Epoch 114/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 114: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0087 - val_loss: 0.0070 - lr: 0.0010
# Epoch 115/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 115: val_loss did not improve from 0.00614
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0088 - val_loss: 0.0101 - lr: 0.0010
# Epoch 116/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 116: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0110 - val_loss: 0.0096 - lr: 0.0010
# Epoch 117/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 117: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0092 - val_loss: 0.0131 - lr: 0.0010
# Epoch 118/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 118: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0096 - val_loss: 0.0210 - lr: 0.0010
# Epoch 119/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 119: val_loss did not improve from 0.00614
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0096 - val_loss: 0.0112 - lr: 0.0010
# Epoch 120/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 120: val_loss did not improve from 0.00614
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0087 - val_loss: 0.0093 - lr: 0.0010
# Epoch 121/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 121: val_loss improved from 0.00614 to 0.00611, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0097 - val_loss: 0.0061 - lr: 0.0010
# Epoch 122/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 122: val_loss did not improve from 0.00611
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0080 - val_loss: 0.0066 - lr: 0.0010
# Epoch 123/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 123: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0099 - val_loss: 0.0084 - lr: 0.0010
# Epoch 124/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 124: val_loss did not improve from 0.00611
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0100 - val_loss: 0.0083 - lr: 0.0010
# Epoch 125/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 125: val_loss did not improve from 0.00611
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0089 - val_loss: 0.0084 - lr: 0.0010
# Epoch 126/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 126: val_loss did not improve from 0.00611
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0081 - val_loss: 0.0094 - lr: 0.0010
# Epoch 127/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 127: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0097 - val_loss: 0.0125 - lr: 0.0010
# Epoch 128/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 128: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0087 - val_loss: 0.0073 - lr: 0.0010
# Epoch 129/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 129: val_loss did not improve from 0.00611
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0084 - val_loss: 0.0083 - lr: 0.0010
# Epoch 130/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0101
# Epoch 130: val_loss did not improve from 0.00611
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0101 - val_loss: 0.0145 - lr: 0.0010
# Epoch 131/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 131: val_loss did not improve from 0.00611
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0090 - val_loss: 0.0072 - lr: 0.0010
# Epoch 132/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 132: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0084 - val_loss: 0.0098 - lr: 0.0010
# Epoch 133/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 133: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0078 - val_loss: 0.0097 - lr: 0.0010
# Epoch 134/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 134: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0080 - val_loss: 0.0080 - lr: 0.0010
# Epoch 135/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 135: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0089 - val_loss: 0.0100 - lr: 0.0010
# Epoch 136/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 136: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0081 - val_loss: 0.0091 - lr: 0.0010
# Epoch 137/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 137: val_loss did not improve from 0.00611
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0085 - val_loss: 0.0069 - lr: 0.0010
# Epoch 138/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 138: val_loss did not improve from 0.00611
# 300/300 [==============================] - 13s 45ms/step - loss: 0.0086 - val_loss: 0.0075 - lr: 0.0010
# Epoch 139/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 139: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0084 - val_loss: 0.0074 - lr: 0.0010
# Epoch 140/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 140: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0097 - val_loss: 0.0077 - lr: 0.0010
# Epoch 141/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 141: val_loss improved from 0.00611 to 0.00611, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0077 - val_loss: 0.0061 - lr: 0.0010
# Epoch 142/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 142: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0089 - val_loss: 0.0068 - lr: 0.0010
# Epoch 143/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 143: val_loss did not improve from 0.00611
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0083 - val_loss: 0.0074 - lr: 0.0010
# Epoch 144/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 144: val_loss improved from 0.00611 to 0.00609, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0096 - val_loss: 0.0061 - lr: 0.0010
# Epoch 145/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 145: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0089 - val_loss: 0.0075 - lr: 0.0010
# Epoch 146/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 146: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0093 - val_loss: 0.0174 - lr: 0.0010
# Epoch 147/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 147: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0084 - val_loss: 0.0111 - lr: 0.0010
# Epoch 148/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 148: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0078 - val_loss: 0.0110 - lr: 0.0010
# Epoch 149/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 149: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0090 - val_loss: 0.0075 - lr: 0.0010
# Epoch 150/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 150: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0082 - val_loss: 0.0074 - lr: 0.0010
# Epoch 151/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 151: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0081 - val_loss: 0.0062 - lr: 0.0010
# Epoch 152/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 152: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0082 - val_loss: 0.0070 - lr: 0.0010
# Epoch 153/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0093
# Epoch 153: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0093 - val_loss: 0.0083 - lr: 0.0010
# Epoch 154/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 154: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0082 - val_loss: 0.0069 - lr: 0.0010
# Epoch 155/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 155: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0081 - val_loss: 0.0067 - lr: 0.0010
# Epoch 156/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 156: val_loss did not improve from 0.00609
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0073 - val_loss: 0.0062 - lr: 0.0010
# Epoch 157/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 157: val_loss improved from 0.00609 to 0.00591, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0077 - val_loss: 0.0059 - lr: 0.0010
# Epoch 158/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 158: val_loss did not improve from 0.00591
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0084 - val_loss: 0.0091 - lr: 0.0010
# Epoch 159/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 159: val_loss did not improve from 0.00591
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0089 - val_loss: 0.0062 - lr: 0.0010
# Epoch 160/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 160: val_loss improved from 0.00591 to 0.00571, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0081 - val_loss: 0.0057 - lr: 0.0010
# Epoch 161/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 161: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0100 - val_loss: 0.0065 - lr: 0.0010
# Epoch 162/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 162: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0075 - val_loss: 0.0077 - lr: 0.0010
# Epoch 163/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 163: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0083 - val_loss: 0.0059 - lr: 0.0010
# Epoch 164/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 164: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0082 - val_loss: 0.0098 - lr: 0.0010
# Epoch 165/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 165: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0081 - val_loss: 0.0061 - lr: 0.0010
# Epoch 166/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 166: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0078 - val_loss: 0.0090 - lr: 0.0010
# Epoch 167/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 167: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0081 - val_loss: 0.0074 - lr: 0.0010
# Epoch 168/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 168: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0081 - val_loss: 0.0127 - lr: 0.0010
# Epoch 169/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 169: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0081 - val_loss: 0.0102 - lr: 0.0010
# Epoch 170/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 170: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0082 - val_loss: 0.0085 - lr: 0.0010
# Epoch 171/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 171: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 45ms/step - loss: 0.0079 - val_loss: 0.0071 - lr: 0.0010
# Epoch 172/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 172: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0087 - val_loss: 0.0079 - lr: 0.0010
# Epoch 173/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 173: val_loss did not improve from 0.00571
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0080 - val_loss: 0.0073 - lr: 0.0010
# Epoch 174/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 174: val_loss improved from 0.00571 to 0.00534, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0073 - val_loss: 0.0053 - lr: 0.0010
# Epoch 175/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 175: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0083 - val_loss: 0.0175 - lr: 0.0010
# Epoch 176/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0073
# Epoch 176: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0073 - val_loss: 0.0066 - lr: 0.0010
# Epoch 177/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 177: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0077 - val_loss: 0.0058 - lr: 0.0010
# Epoch 178/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 178: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0072 - val_loss: 0.0144 - lr: 0.0010
# Epoch 179/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 179: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0087 - val_loss: 0.0064 - lr: 0.0010
# Epoch 180/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 180: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0077 - val_loss: 0.0093 - lr: 0.0010
# Epoch 181/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 181: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0084 - val_loss: 0.0055 - lr: 0.0010
# Epoch 182/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 182: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0071 - val_loss: 0.0080 - lr: 0.0010
# Epoch 183/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 183: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0076 - val_loss: 0.0062 - lr: 0.0010
# Epoch 184/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0071
# Epoch 184: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0071 - val_loss: 0.0062 - lr: 0.0010
# Epoch 185/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 185: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0081 - val_loss: 0.0069 - lr: 0.0010
# Epoch 186/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 186: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0080 - val_loss: 0.0074 - lr: 0.0010
# Epoch 187/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 187: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0075 - val_loss: 0.0074 - lr: 0.0010
# Epoch 188/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 188: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0080 - val_loss: 0.0067 - lr: 0.0010
# Epoch 189/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 189: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0069 - val_loss: 0.0072 - lr: 0.0010
# Epoch 190/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 190: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0076 - val_loss: 0.0075 - lr: 0.0010
# Epoch 191/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 191: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0077 - val_loss: 0.0144 - lr: 0.0010
# Epoch 192/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 192: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0076 - val_loss: 0.0066 - lr: 0.0010
# Epoch 193/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 193: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0068 - val_loss: 0.0062 - lr: 0.0010
# Epoch 194/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0079
# Epoch 194: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0079 - val_loss: 0.0085 - lr: 0.0010
# Epoch 195/1000
# 300/300 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 195: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0072 - val_loss: 0.0064 - lr: 0.0010
# Epoch 196/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 196: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0069 - val_loss: 0.0061 - lr: 0.0010
# Epoch 197/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 197: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0076 - val_loss: 0.0091 - lr: 0.0010
# Epoch 198/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 198: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0074 - val_loss: 0.0092 - lr: 0.0010
# Epoch 199/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 199: val_loss did not improve from 0.00534
# 300/300 [==============================] - 14s 46ms/step - loss: 0.0079 - val_loss: 0.0055 - lr: 0.0010
# Epoch 200/1000
# 299/300 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 200: val_loss did not improve from 0.00534
# ...
# Epoch 939/1000
# 299/300 [============================>.] - ETA: 0s - loss: 3.4427e-04
# Epoch 939: val_loss did not improve from 0.00038
# 300/300 [==============================] - 16s 52ms/step - loss: 3.4370e-04 - val_loss: 6.0095e-04 - lr: 1.2500e-04
# Epoch 940/1000
# 299/300 [============================>.] - ETA: 0s - loss: 3.0251e-04
# Epoch 940: val_loss did not improve from 0.00038
# 300/300 [==============================] - 16s 53ms/step - loss: 3.0248e-04 - val_loss: 5.1398e-04 - lr: 1.2500e-04
# Epoch 941/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.8954e-04
# Epoch 941: val_loss did not improve from 0.00038
#
# Epoch 941: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 300/300 [==============================] - 16s 53ms/step - loss: 2.8954e-04 - val_loss: 4.3845e-04 - lr: 1.2500e-04
# Epoch 942/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.8082e-04
# Epoch 942: val_loss improved from 0.00038 to 0.00036, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 16s 54ms/step - loss: 1.8075e-04 - val_loss: 3.5825e-04 - lr: 6.2500e-05
# Epoch 943/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.0862e-04
# Epoch 943: val_loss did not improve from 0.00036
# 300/300 [==============================] - 18s 59ms/step - loss: 2.0862e-04 - val_loss: 4.9734e-04 - lr: 6.2500e-05
# Epoch 944/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.9052e-04
# Epoch 944: val_loss did not improve from 0.00036
# 300/300 [==============================] - 16s 53ms/step - loss: 1.9044e-04 - val_loss: 3.7463e-04 - lr: 6.2500e-05
# Epoch 945/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.2164e-04
# Epoch 945: val_loss did not improve from 0.00036
# 300/300 [==============================] - 16s 54ms/step - loss: 2.2164e-04 - val_loss: 3.8482e-04 - lr: 6.2500e-05
# Epoch 946/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.8569e-04
# Epoch 946: val_loss did not improve from 0.00036
# 300/300 [==============================] - 16s 53ms/step - loss: 1.8569e-04 - val_loss: 3.6226e-04 - lr: 6.2500e-05
# Epoch 947/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.2111e-04
# Epoch 947: val_loss did not improve from 0.00036
# 300/300 [==============================] - 18s 58ms/step - loss: 2.2111e-04 - val_loss: 4.9547e-04 - lr: 6.2500e-05
# Epoch 948/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.1673e-04
# Epoch 948: val_loss improved from 0.00036 to 0.00035, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 18s 60ms/step - loss: 2.1673e-04 - val_loss: 3.5434e-04 - lr: 6.2500e-05
# Epoch 949/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.7621e-04
# Epoch 949: val_loss improved from 0.00035 to 0.00035, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 16s 54ms/step - loss: 1.7612e-04 - val_loss: 3.5363e-04 - lr: 6.2500e-05
# Epoch 950/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.1540e-04
# Epoch 950: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 55ms/step - loss: 2.1549e-04 - val_loss: 3.9081e-04 - lr: 6.2500e-05
# Epoch 951/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.0411e-04
# Epoch 951: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 53ms/step - loss: 2.0411e-04 - val_loss: 3.8476e-04 - lr: 6.2500e-05
# Epoch 952/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.1659e-04
# Epoch 952: val_loss did not improve from 0.00035
# 300/300 [==============================] - 21s 70ms/step - loss: 2.1659e-04 - val_loss: 3.7962e-04 - lr: 6.2500e-05
# Epoch 953/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.9466e-04
# Epoch 953: val_loss did not improve from 0.00035
# 300/300 [==============================] - 17s 56ms/step - loss: 1.9454e-04 - val_loss: 3.7858e-04 - lr: 6.2500e-05
# Epoch 954/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.9613e-04
# Epoch 954: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 53ms/step - loss: 1.9613e-04 - val_loss: 3.9279e-04 - lr: 6.2500e-05
# Epoch 955/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.0481e-04
# Epoch 955: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 54ms/step - loss: 2.0471e-04 - val_loss: 3.6144e-04 - lr: 6.2500e-05
# Epoch 956/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.0444e-04
# Epoch 956: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 53ms/step - loss: 2.0425e-04 - val_loss: 3.6617e-04 - lr: 6.2500e-05
# Epoch 957/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.9305e-04
# Epoch 957: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 54ms/step - loss: 1.9316e-04 - val_loss: 3.5692e-04 - lr: 6.2500e-05
# Epoch 958/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.2543e-04
# Epoch 958: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 55ms/step - loss: 2.2522e-04 - val_loss: 3.6194e-04 - lr: 6.2500e-05
# Epoch 959/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.8640e-04
# Epoch 959: val_loss did not improve from 0.00035
# 300/300 [==============================] - 17s 58ms/step - loss: 1.8640e-04 - val_loss: 3.6587e-04 - lr: 6.2500e-05
# Epoch 960/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.9242e-04
# Epoch 960: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 53ms/step - loss: 1.9252e-04 - val_loss: 4.5795e-04 - lr: 6.2500e-05
# Epoch 961/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.0581e-04
# Epoch 961: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 53ms/step - loss: 2.0603e-04 - val_loss: 3.9428e-04 - lr: 6.2500e-05
# Epoch 962/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.0475e-04
# Epoch 962: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 54ms/step - loss: 2.0484e-04 - val_loss: 3.8705e-04 - lr: 6.2500e-05
# Epoch 963/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.0327e-04
# Epoch 963: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 53ms/step - loss: 2.0355e-04 - val_loss: 4.9617e-04 - lr: 6.2500e-05
# Epoch 964/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.9488e-04
# Epoch 964: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 54ms/step - loss: 1.9461e-04 - val_loss: 6.1140e-04 - lr: 6.2500e-05
# Epoch 965/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.2877e-04
# Epoch 965: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 52ms/step - loss: 2.2889e-04 - val_loss: 3.6631e-04 - lr: 6.2500e-05
# Epoch 966/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.0108e-04
# Epoch 966: val_loss improved from 0.00035 to 0.00035, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 16s 53ms/step - loss: 2.0128e-04 - val_loss: 3.5059e-04 - lr: 6.2500e-05
# Epoch 967/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.7629e-04
# Epoch 967: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 52ms/step - loss: 1.7631e-04 - val_loss: 3.8660e-04 - lr: 6.2500e-05
# Epoch 968/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.3268e-04
# Epoch 968: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 52ms/step - loss: 2.3268e-04 - val_loss: 3.9916e-04 - lr: 6.2500e-05
# Epoch 969/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.8530e-04
# Epoch 969: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 53ms/step - loss: 1.8530e-04 - val_loss: 3.6815e-04 - lr: 6.2500e-05
# Epoch 970/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.8469e-04
# Epoch 970: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 53ms/step - loss: 1.8469e-04 - val_loss: 3.5677e-04 - lr: 6.2500e-05
# Epoch 971/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.1233e-04
# Epoch 971: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 52ms/step - loss: 2.1222e-04 - val_loss: 4.0288e-04 - lr: 6.2500e-05
# Epoch 972/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.9973e-04
# Epoch 972: val_loss did not improve from 0.00035
# 300/300 [==============================] - 16s 52ms/step - loss: 1.9948e-04 - val_loss: 3.5203e-04 - lr: 6.2500e-05
# Epoch 973/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.9555e-04
# Epoch 973: val_loss did not improve from 0.00035
# 300/300 [==============================] - 18s 61ms/step - loss: 1.9555e-04 - val_loss: 5.0735e-04 - lr: 6.2500e-05
# Epoch 974/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.9686e-04
# Epoch 974: val_loss improved from 0.00035 to 0.00034, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 16s 54ms/step - loss: 1.9686e-04 - val_loss: 3.4494e-04 - lr: 6.2500e-05
# Epoch 975/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.1106e-04
# Epoch 975: val_loss did not improve from 0.00034
# 300/300 [==============================] - 18s 60ms/step - loss: 2.1088e-04 - val_loss: 4.1730e-04 - lr: 6.2500e-05
# Epoch 976/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.8635e-04
# Epoch 976: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 53ms/step - loss: 1.8635e-04 - val_loss: 3.5699e-04 - lr: 6.2500e-05
# Epoch 977/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.2875e-04
# Epoch 977: val_loss did not improve from 0.00034
# 300/300 [==============================] - 19s 64ms/step - loss: 2.2839e-04 - val_loss: 4.2729e-04 - lr: 6.2500e-05
# Epoch 978/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.7186e-04
# Epoch 978: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 52ms/step - loss: 1.7173e-04 - val_loss: 3.5859e-04 - lr: 6.2500e-05
# Epoch 979/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.8175e-04
# Epoch 979: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 53ms/step - loss: 1.8181e-04 - val_loss: 4.2229e-04 - lr: 6.2500e-05
# Epoch 980/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.7822e-04
# Epoch 980: val_loss did not improve from 0.00034
# 300/300 [==============================] - 17s 58ms/step - loss: 2.7822e-04 - val_loss: 3.9037e-04 - lr: 6.2500e-05
# Epoch 981/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.8792e-04
# Epoch 981: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 55ms/step - loss: 1.8781e-04 - val_loss: 4.0099e-04 - lr: 6.2500e-05
# Epoch 982/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.3547e-04
# Epoch 982: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 52ms/step - loss: 2.3547e-04 - val_loss: 3.7483e-04 - lr: 6.2500e-05
# Epoch 983/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.9078e-04
# Epoch 983: val_loss improved from 0.00034 to 0.00034, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 16s 52ms/step - loss: 1.9051e-04 - val_loss: 3.4035e-04 - lr: 6.2500e-05
# Epoch 984/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.7016e-04
# Epoch 984: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 54ms/step - loss: 1.7149e-04 - val_loss: 4.1411e-04 - lr: 6.2500e-05
# Epoch 985/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.1402e-04
# Epoch 985: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 53ms/step - loss: 2.1392e-04 - val_loss: 6.9258e-04 - lr: 6.2500e-05
# Epoch 986/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.1004e-04
# Epoch 986: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 52ms/step - loss: 2.1004e-04 - val_loss: 3.5399e-04 - lr: 6.2500e-05
# Epoch 987/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.9033e-04
# Epoch 987: val_loss did not improve from 0.00034
# 300/300 [==============================] - 19s 63ms/step - loss: 1.9033e-04 - val_loss: 3.8258e-04 - lr: 6.2500e-05
# Epoch 988/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.9662e-04
# Epoch 988: val_loss did not improve from 0.00034
# 300/300 [==============================] - 18s 59ms/step - loss: 1.9645e-04 - val_loss: 3.5371e-04 - lr: 6.2500e-05
# Epoch 989/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.8466e-04
# Epoch 989: val_loss improved from 0.00034 to 0.00034, saving model to data/models\silica_medium_relu.keras
# 300/300 [==============================] - 16s 52ms/step - loss: 1.8466e-04 - val_loss: 3.3503e-04 - lr: 6.2500e-05
# Epoch 990/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.0398e-04
# Epoch 990: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 52ms/step - loss: 2.0373e-04 - val_loss: 3.4994e-04 - lr: 6.2500e-05
# Epoch 991/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.0208e-04
# Epoch 991: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 53ms/step - loss: 2.0208e-04 - val_loss: 4.8655e-04 - lr: 6.2500e-05
# Epoch 992/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.9450e-04
# Epoch 992: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 53ms/step - loss: 1.9450e-04 - val_loss: 4.0621e-04 - lr: 6.2500e-05
# Epoch 993/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.7969e-04
# Epoch 993: val_loss did not improve from 0.00034
# 300/300 [==============================] - 17s 55ms/step - loss: 1.7969e-04 - val_loss: 4.5747e-04 - lr: 6.2500e-05
# Epoch 994/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.1189e-04
# Epoch 994: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 53ms/step - loss: 2.1189e-04 - val_loss: 3.7181e-04 - lr: 6.2500e-05
# Epoch 995/1000
# 299/300 [============================>.] - ETA: 0s - loss: 1.8165e-04
# Epoch 995: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 53ms/step - loss: 1.8159e-04 - val_loss: 3.4391e-04 - lr: 6.2500e-05
# Epoch 996/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.2814e-04
# Epoch 996: val_loss did not improve from 0.00034
# 300/300 [==============================] - 18s 59ms/step - loss: 2.2811e-04 - val_loss: 3.6034e-04 - lr: 6.2500e-05
# Epoch 997/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.8301e-04
# Epoch 997: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 52ms/step - loss: 1.8301e-04 - val_loss: 3.7542e-04 - lr: 6.2500e-05
# Epoch 998/1000
# 300/300 [==============================] - ETA: 0s - loss: 1.8494e-04
# Epoch 998: val_loss did not improve from 0.00034
# 300/300 [==============================] - 17s 56ms/step - loss: 1.8494e-04 - val_loss: 3.5413e-04 - lr: 6.2500e-05
# Epoch 999/1000
# 300/300 [==============================] - ETA: 0s - loss: 2.3186e-04
# Epoch 999: val_loss did not improve from 0.00034
# 300/300 [==============================] - 17s 57ms/step - loss: 2.3186e-04 - val_loss: 3.5628e-04 - lr: 6.2500e-05
# Epoch 1000/1000
# 299/300 [============================>.] - ETA: 0s - loss: 2.1920e-04
# Epoch 1000: val_loss did not improve from 0.00034
# 300/300 [==============================] - 16s 52ms/step - loss: 2.1914e-04 - val_loss: 3.5131e-04 - lr: 6.2500e-05

# %%
# load model
model = tf.keras.models.load_model('data/models/carbon_medium_relu.keras', custom_objects={'abs': tf.math.abs})

# %%
# predict x_train
prediction = model.predict(np.array(x_train))
# Out:
# 9375/9375 [==============================] - 26s 3ms/step

# %%
# test on x_train
pore_widths = np.load("data/initial kernels/Size_Kernel_Carbon_Adsorption.npy")
pressures = np.load("data/initial kernels/Pressure_Carbon.npy")
NX, NY = 4 , 5
figure, axis = plt.subplots(NX, NY)
for i in range(NX):
    for j in range(NY):
        k = np.random.randint(0, len(x_train))
        x_scale_factor = max(pore_widths)/len(x_train[k])
        axis[i, j].plot(pore_widths/x_scale_factor, prediction[k], marker=".", label=f"Prediction") 
        axis[i, j].plot(pore_widths/x_scale_factor, y_train[k], marker=".", label="Real distribution")
        axis[i, j].plot(x_train[k], label="Isotherm")
        axis[i, j].set_title(f"№ {k}")
        axis[i, j].title.set_size(10)
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.95)
plt.legend()
plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 10
#       8 k = np.random.randint(0, len(x_train))
#       9 x_scale_factor = max(pore_widths)/len(x_train[k])
# ---> 10 axis[i, j].plot(pore_widths/x_scale_factor, prediction[k], marker=".", label=f"Prediction")
#      11 axis[i, j].plot(pore_widths/x_scale_factor, y_train[k], marker=".", label="Real distribution")
#      12 axis[i, j].plot(x_train[k], label="Isotherm")
#
# File ~\PycharmProjects\isotherm\venv10\lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~\PycharmProjects\isotherm\venv10\lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\PycharmProjects\isotherm\venv10\lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (130,) and (128,)

# %%
# test with test Generator
from tools import TestApp
# gen = Generator(path_s="data/initial kernels/Kernel_Silica_Adsorption.npy",
#                     path_d="data/initial kernels/Kernel_Silica_Desorption.npy",
#                     path_p_d="data/initial kernels/Pressure_Silica.npy",
#                     path_p_s="data/initial kernels/Pressure_Silica.npy",
#                     path_a="data/initial kernels/Size_Kernel_Silica_Adsorption.npy"
#                     )
gen = Generator(path_s="data/initial kernels/Kernel_Carbon_Adsorption.npy",
                              path_d="data/initial kernels/Kernel_Carbon_Desorption.npy",
                              path_p_d="data/initial kernels/Pressure_Carbon.npy",
                              path_p_s="data/initial kernels/Pressure_Carbon.npy",
                              path_a="data/initial kernels/Size_Kernel_Carbon_Adsorption.npy"
                            )
TestApp.App(model, gen)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 15
#       3 # gen = Generator(path_s="data/initial kernels/Kernel_Silica_Adsorption.npy",
#       4 #                     path_d="data/initial kernels/Kernel_Silica_Desorption.npy",
#       5 #                     path_p_d="data/initial kernels/Pressure_Silica.npy",
#       6 #                     path_p_s="data/initial kernels/Pressure_Silica.npy",
#       7 #                     path_a="data/initial kernels/Size_Kernel_Silica_Adsorption.npy"
#       8 #                     )
#       9 gen = Generator(path_s="data/initial kernels/Kernel_Carbon_Adsorption.npy",
#      10                               path_d="data/initial kernels/Kernel_Carbon_Desorption.npy",
#      11                               path_p_d="data/initial kernels/Pressure_Carbon.npy",
#      12                               path_p_s="data/initial kernels/Pressure_Carbon.npy",
#      13                               path_a="data/initial kernels/Size_Kernel_Carbon_Adsorption.npy"
#      14                             )
# ---> 15 TestApp.App(model, gen)
#
# File ~\PycharmProjects\isotherm\tools\TestApp.py:36, in App.__init__(self, model, gen)
#      34 self.sigma2 = 1
#      35 self.a = 0.5
# ---> 36 self.visualizeGraph()
#      38 graphBox1 = self.fig.add_axes([0.1, 0.02, 0.05, 0.03])
#      39 graphBox2 = self.fig.add_axes([0.2, 0.02, 0.05, 0.03])
#
# File ~\PycharmProjects\isotherm\tools\TestApp.py:73, in App.visualizeGraph(self, *args, **kwargs)
#      71 data_to_net = data_to_net / max(data_to_net)
#      72 #
# ---> 73 fit = self.model.predict(np.array([data_to_net])).T
#      74 fit = fit / max(fit)
#      76 self.isotherm_line.set_ydata(self.gen.n_s)
#
# File ~\PycharmProjects\isotherm\venv10\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_file3hzghdg1.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\ivano\PycharmProjects\isotherm\venv10\lib\site-packages\keras\engine\training.py", line 2041, in predict_function  *
#         return step_function(self, iterator)
#     File "C:\Users\ivano\PycharmProjects\isotherm\venv10\lib\site-packages\keras\engine\training.py", line 2027, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\ivano\PycharmProjects\isotherm\venv10\lib\site-packages\keras\engine\training.py", line 2015, in run_step  **
#         outputs = model.predict_step(data)
#     File "C:\Users\ivano\PycharmProjects\isotherm\venv10\lib\site-packages\keras\engine\training.py", line 1983, in predict_step
#         return self(x, training=False)
#     File "C:\Users\ivano\PycharmProjects\isotherm\venv10\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\ivano\PycharmProjects\isotherm\venv10\lib\site-packages\keras\engine\input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 507), found shape=(None, 418)

# %%
# Test on experimental data
#exp_file = "MCM-41-adsorb"
exp_file_list = ["MCM-41-adsorb", "SBA-15", "SBA-16", "MIL-101", "MIL-101_2"]
exp_data_list = [np.loadtxt(f"data/real/{i}.txt") for i in exp_file_list]
p_exp_list = []
n_s_exp_raw_list = []
for exp_data in exp_data_list:
    p_exp_list.append(exp_data.T[0])
    n_s_exp_raw_list.append(exp_data.T[1])
# p_exp = np.empty(len(exp_data))
# n_exp = np.empty(len(exp_data))
# for i in range(len(exp_data)):  # Загружаем адсорбцию и давления
#     p_exp[i] = exp_data[i][0]
#     n_exp[i] = exp_data[i][1]
# j = np.argmax(n_exp) + 1  # Отделяем адсорбционную ветку
# n_s_exp_raw = n_exp[:j]
# p_exp_sorb = p_exp[:j]

# %%
j = 2
plt.plot(p_exp_list[j], n_s_exp_raw_list[j], marker=".", label=exp_file_list[j])
plot()

# %%
# интерполируем экспериментальную изотерму под давления кернала
n_s_exp_list = []
for i in range(len(p_exp_list)):
    n_s_exp_list.append(np.interp(gen.pressures_s[40:547], p_exp_list[i], n_s_exp_raw_list[i]))

# %%
j = 2
plt.plot(gen.pressures_s[40:547], n_s_exp_list[j], marker=".", label=exp_file_list[j])
plot()

# %%
n_s_exp_for_net_list = [pre_process_isotherm(n_s_exp) for n_s_exp in n_s_exp_list]
fit_exp_list = [model.predict(np.array([n_s_exp_for_net])).T for n_s_exp_for_net in n_s_exp_for_net_list]
# Out:
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
NX, NY = 2 , 3
figure, axis = plt.subplots(NX, NY)
k = 0
for i in range(NX):
    for j in range(NY):
        x_scale_factor = max(gen.a_array)/max(p_exp_list[k])
        y_scale_factor = max(fit_exp_list[k])/max(n_s_exp_raw_list[k])
        axis[i, j].plot(pore_widths, fit_exp_list[k], marker=".", label=f"Distribution") 
        axis[i, j].plot(p_exp_list[k]*x_scale_factor, n_s_exp_raw_list[k]*y_scale_factor, label=f"{exp_file_list[k]}", marker=".")
        axis[i, j].set_title(f"max at {round(gen.a_array[np.argmax(fit_exp_list[k])], 2)} nm")
        axis[i, j].title.set_size(12)
        axis[i, j].legend(loc="upper right")
        axis[i, j].grid()
        k += 1
        if k >= len(fit_exp_list):
            break
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.95)
plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
### Classic
from inverse import fit_SLSQP
kernel = np.load("data/initial kernels/Kernel_Carbon_Adsorption.npy")
cut_kernel = []
for i in range(len(kernel)):
    cut_kernel.append(kernel[i][40:547])
cut_kernel = np.array(cut_kernel)
fit_classic_list = [fit_SLSQP(adsorption=n_s, kernel=cut_kernel, a_array=pore_widths) for n_s in n_s_exp_list]

# %%
NX, NY = 2 , 3
figure, axis = plt.subplots(NX, NY)
k = 0
for i in range(NX):
    for j in range(NY):
        x_scale_factor = max(gen.a_array)/max(p_exp_list[k])
        y_scale_factor = max(fit_classic_list[k].x)/max(n_s_exp_raw_list[k])
        axis[i, j].plot(pore_widths, fit_classic_list[k].x, marker=".", label=f"Distribution") 
        axis[i, j].plot(p_exp_list[k]*x_scale_factor, n_s_exp_raw_list[k]*y_scale_factor, label=f"{exp_file_list[k]}", marker=".")
        axis[i, j].set_title(f"max at {round(gen.a_array[np.argmax(fit_classic_list[k].x)], 2)} nm")
        axis[i, j].title.set_size(12)
        axis[i, j].legend(loc="upper right")
        axis[i, j].grid()
        k += 1
        if k >= len(fit_exp_list):
            break
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.95)
plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# compare net and classic
NX, NY = 2 , 3
figure, axis = plt.subplots(NX, NY)
k = 0
for i in range(NX):
    for j in range(NY):
        y_scale_factor = max(fit_classic_list[k].x)/max(fit_exp_list[k])
        axis[i, j].plot(pore_widths, fit_exp_list[k]*y_scale_factor, marker=".", label=f"net") 
        axis[i, j].plot(pore_widths, fit_classic_list[k].x, marker=".", label=f"classic") 
        axis[i, j].set_title(f"{exp_file_list[k]}")
        axis[i, j].title.set_size(12)
        axis[i, j].legend(loc="upper right")
        axis[i, j].grid()
        k += 1
        if k >= len(fit_exp_list):
            break
plt.subplots_adjust(hspace=0.6, right=0.95, left=0.05, bottom=0.05, top=0.95)
plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
